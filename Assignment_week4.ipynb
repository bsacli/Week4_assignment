# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Banu**
#
# PhD Student

# %% [markdown]
# *I like playing with data :) I like to discover insights of data.*

# %% [markdown]
# ### This code multiplies 2 and 3, and displays the result.

# %%
print (2*3)
# Out:
# 6

# %% [markdown]
# Open Scale helps you ensure your model is
# - fair.
# - explainable.
# - compliant.

# %% [markdown]
# [IBM Data Science Professional Certificate Program](https://www.coursera.org/professional-certificates/ibm-data-science) is the best starting point to being a data scientist.

# %% [markdown]
# | Patient       | Age           | Sex    |
# | ------------- |:-------------:| -----: |
# | PD1           | 34            | Female |
# | PD2           | 58            | Male   |
# | PD3           | 62            | Male   |

# %% [markdown]
# The most essential features of a data scientist: <br />
#     1. Curious <br />
#     2. Argumentative <br />
#     3. Judgemental
